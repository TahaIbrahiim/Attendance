# %%
import cv2
import numpy as np
import face_recognition
import os
from datetime import datetime

# %%
path = 'img'
images = []
classNames = []
myList = os.listdir(path)
print(myList)
# Out:
# ['Eslam Zoghla.jpg', 'Mohamed sabry.jpg', 'Soliman Mahmoud.jpg', 'yahya hamza.jpg']

# %%
for cl in myList:
    curImg = cv2.imread(f'{path}/{cl}')
    images.append(curImg)
    classNames.append(os.path.splitext(cl)[0])
print(classNames)
# Out:
# ['Eslam Zoghla', 'Mohamed sabry', 'Soliman Mahmoud', 'yahya hamza']

# %%
def findEncodings(images):
    encodeList = []
    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encode = face_recognition.face_encodings(img)[0]
        encodeList.append(encode)
    return encodeList

# %%
def markAttendance(name):
    with open('Attendance.csv','r+') as f:
        myDataList = f.readlines()
        nameList = []
        for line in myDataList:
            entry = line.split(',')
            nameList.append(entry[0])
        if name not in nameList:
            now = datetime.now()
            dtString = now.strftime('%H:%M:%S')
            f.writelines(f'\n{name},{dtString}')
        

encodeListKnown = findEncodings(images)
print('Encoding Complete')
# Out:
# Encoding Complete

# %%
cap = cv2.VideoCapture(0)
frame_resizing = 0.25

while True:
    success, img = cap.read()
    imgS = cv2.resize(img, (0, 0), fx=frame_resizing, fy=frame_resizing)
    imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)
 
    facesCurFrame = face_recognition.face_locations(imgS)
    encodesCurFrame = face_recognition.face_encodings(imgS,facesCurFrame)
 
    for encodeFace,faceLoc in zip(encodesCurFrame,facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown,encodeFace)
        print('matches',matches)
        faceDis = face_recognition.face_distance(encodeListKnown,encodeFace)
        print(faceDis)
        matchIndex = np.argmin(faceDis)
        if matches[matchIndex]:
            name = classNames[matchIndex].upper()
            print(name)
            
            faceLoc = np.array(faceLoc)
            faceLoc = faceLoc / 0.25
            faceLoc=faceLoc.astype(int)
            #y1,x2,y2,x1 = faceLoc # in the other code we risize the face
            #y1, x2, y2, x1 = y1*4,x2*4,y2*4,x1*4
            y1, x2, y2, x1 = faceLoc[0], faceLoc[1], faceLoc[2], faceLoc[3]
         
            cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)
            cv2.rectangle(img,(x1,y2-35),(x2,y2),(0,255,0),cv2.FILLED)
            cv2.putText(img,name,(x1+6,y2-6),cv2.FONT_HERSHEY_COMPLEX,1,(255,255,255),2)
            print("Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor")
 
    cv2.imshow('Webcam',img)
    key = cv2.waitKey(1)
    if key == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# matches [True, False, True, True]
# [0.40323817 0.85257616 0.5643085  0.56188613]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.40808666 0.8085605  0.55144683 0.50499996]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.42315089 0.84755843 0.57656626 0.50653596]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.44293085 0.88361647 0.5646287  0.51501482]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.40830737 0.83741244 0.5545833  0.51404529]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.41852989 0.82837984 0.61038908 0.534176  ]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.40499429 0.84344587 0.60700209 0.56277362]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39663417 0.86119446 0.58950139 0.53628536]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.35951256 0.82982055 0.60043554 0.54017778]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.38852014 0.85033248 0.56593732 0.53123173]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39380323 0.83745022 0.57747756 0.56315258]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.41814724 0.84002413 0.6510661  0.47689222]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.45883259 0.84853969 0.63840326 0.45810849]
# YAHYA HAMZA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.35966837 0.80576225 0.55851393 0.51672202]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.41382026 0.83323714 0.57879207 0.57002825]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.35248461 0.83989478 0.59622181 0.55157508]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.

# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.41700602 0.81661121 0.61766191 0.51343994]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, True]
# [0.4505425  0.81138415 0.62188478 0.51085216]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.45008123 0.83022387 0.57227365 0.49083616]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.40857593 0.82491288 0.57653744 0.53860588]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39354518 0.80217284 0.55206637 0.55603557]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.3944385  0.81147984 0.54629146 0.56549675]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39731681 0.80830304 0.57104759 0.54816688]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, False]
# [0.42394292 0.84010496 0.60387761 0.60677502]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, False]
# [0.44275159 0.84679413 0.61417777 0.62307499]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.40840009 0.85281675 0.57426116 0.58524684]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.37652866 0.82756616 0.54814311 0.57127342]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.41572548 0.85272591 0.55557279 0.56070739]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39801267 0.81412956 0.54754851 0.57979662]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.39380994 0.83667702 0.57587471 0.58838478]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.36477395 0.80933047 0.58782237 0.54638857]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, False]
# [0.3965417  0.79334322 0.58642717 0.60279427]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.37267837 0.82679442 0.56555275 0.58837704]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, False]
# [0.3562876  0.77815495 0.56874006 0.60333919]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.37307993 0.83361733 0.5821781  0.5861334 ]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, True, True]
# [0.34432348 0.80607037 0.57031886 0.57010929]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
# matches [True, False, False, False]
# [0.39743909 0.82662949 0.6080392  0.61013598]
# ESLAM ZOGHLA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor

# %%
from flask import Flask, render_template

# %%
myApp = Flask(__name__)

@myApp.route('/')
def index():
    return render_template('index.html')

@myApp.route('/Eslam')
def name():
    return 'Hello, Eslam'

if __name__ == '__main__':
    myApp.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/May/2024 02:02:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2024 02:02:19] "GET /[object%20ArrayBuffer] HTTP/1.1" 404 -

# %%
import cv2
import numpy as np
import face_recognition
import os


# Resize the image
frame_resizing = 0.25
imgS = cv2.resize(img, (0, 0), fx=frame_resizing, fy=frame_resizing)

# Convert image to RGB (face_recognition library requires RGB format)
imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

# Detect faces in the image
facesCurFrame = face_recognition.face_locations(imgS)
encodesCurFrame = face_recognition.face_encodings(imgS, facesCurFrame)

# Loop through each detected face
for encodeFace, faceLoc in zip(encodesCurFrame, facesCurFrame):
    matches = face_recognition.compare_faces(encodeListKnown, encodeFace)
    print('matches', matches)
    faceDis = face_recognition.face_distance(encodeListKnown, encodeFace)
    print(faceDis)
    matchIndex = np.argmin(faceDis)
    if matches[matchIndex]:
        name = classNames[matchIndex].upper()
        print(name)

        faceLoc = np.array(faceLoc)
        faceLoc = faceLoc / 0.25
        faceLoc = faceLoc.astype(int)
        y1, x2, y2, x1 = faceLoc[0], faceLoc[1], faceLoc[2], faceLoc[3]

        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.rectangle(img, (x1, y2-35), (x2, y2), (0, 255, 0), cv2.FILLED)
        cv2.putText(img, name, (x1+6, y2-6), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
        print("Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor")
# Out:
# matches [True, False, False, True]
# [0.58487213 0.78497533 0.63554488 0.4599531 ]
# YAHYA HAMZA
# Open the Doooooooooooooooooooooooooooooooooooooooooooooooooooooor
